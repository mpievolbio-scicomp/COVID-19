# %%
# %matplotlib notebook

# %%
import pandas
import matplotlib
from matplotlib import pyplot as plt
import os
import datetime

# %%
# Load JHU data

## Update
os.system("git submodule update --recursive")
# Out:
# 0

# %%
jhu_data_raw = pandas.read_csv("../JHU_data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

# %%
jhu_data_raw
# Out:
#                 Province/State         Country/Region        Lat       Long  \
# 0                          NaN            Afghanistan  33.000000  65.000000
# 1                          NaN                Albania  41.153300  20.168300
# 2                          NaN                Algeria  28.033900   1.659600
# 3                          NaN                Andorra  42.506300   1.521800
# 4                          NaN                 Angola -11.202700  17.873900
# ..                         ...                    ...        ...        ...
# 259  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 260                        NaN            South Sudan   6.877000  31.307000
# 261                        NaN         Western Sahara  24.215500 -12.885800
# 262                        NaN  Sao Tome and Principe   0.186360   6.613081
# 263                        NaN                  Yemen  15.552727  48.516388
#
# ...

# %%
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 259    0
# 260    0
# 261    0
# 262    0
# 263    0
# Name: 1/22/20, Length: 264, dtype: int64

# %%
start_date = '2/25/20'

# %%
end_date = '3/16/20'

# %%
cases_germany = jhu_data_raw[jhu_data_raw["Country/Region"]=="Germany"].loc[:,start_date:end_date].transpose()

# %%
cases_germany.plot(logy=True,style="o")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cases_germany.columns=["Germany"]

# %%
cases_germany
# Out:
#          Germany
# 2/25/20       17
# 2/26/20       27
# 2/27/20       46
# 2/28/20       48
# 2/29/20       79
# 3/1/20       130
# 3/2/20       159
# 3/3/20       196
# 3/4/20       262
# 3/5/20       482
# 3/6/20       670
# 3/7/20       799
# 3/8/20      1040
# 3/9/20      1176
# 3/10/20     1457
# 3/11/20     1908
# 3/12/20     2078
# 3/13/20     3675
# 3/14/20     4585
# 3/15/20     5795
# 3/16/20     7272

# %%
#cases_world = jhu_data_raw.iloc[start_date:end_date].sum()
#dates = cases_germany.index
#germany_vs_world = [{"Germany":g, "World":w} for g,w in zip(cases_germany, cases_world.values)]
#data_for_sim = pandas.DataFrame(index=dates, columns=["Germany","World"], data=germany_vs_world, )
cases_germany.set_index(cases_germany.index.rename("Date"),inplace=True)
cases_germany.to_csv("germany_{0:s}-{1:2}.csv".format(start_date.replace('/',''),end_date.replace('/','')))

# %%
# %ls -lrt
# Out:
# total 1024
# -rw-r--r-- 1 grotec mevb    12 Apr  6 11:17 main.m
# -rw-r--r-- 1 grotec mevb   526 Apr  6 11:23 jobscript.sh
# -rw-r--r-- 1 grotec mevb    81 Apr  6 11:24 job.err.14186779
# -rw-r--r-- 1 grotec mevb  4205 Apr  6 11:40 job.out.14186779
# -rw-r--r-- 1 grotec mevb  7229 Apr  7 08:50 single_trajectory.m
# -rw-r--r-- 1 grotec mevb     1 Apr  7 08:58 run_seir.m
# -rw-r--r-- 1 grotec mevb  3765 Apr  7 11:44 wuhan_1-14d.pdf
# -rw-r--r-- 1 grotec mevb     0 Apr 11 06:39 city_coordinates.csv
# -rw-r--r-- 1 grotec mevb  1084 Apr 11 21:06 Mobility_Germany_template.csv
# -rw-r--r-- 1 grotec mevb   552 Apr 11 21:06 Mobility.csv
# -rw-r--r-- 1 grotec mevb   823 Apr 11 23:08 get_data_from_jhu.py
# -rw-r--r-- 1 grotec mevb    50 Apr 12 16:46 pop.csv
# -rw-r--r-- 1 grotec mevb  9215 Apr 12 16:59 SEIR.m
# -rw-r--r-- 1 grotec mevb  3312 Apr 12 17:02 cities.mat
# -rw-r--r-- 1 grotec mevb   187 Apr 12 17:10 pop.mat
# -rw-r--r-- 1 grotec mevb   176 Apr 12 17:14 M.mat
# ...
